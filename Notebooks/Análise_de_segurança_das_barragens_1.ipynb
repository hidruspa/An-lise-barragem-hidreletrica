# %% [markdown]
# <a href="https://colab.research.google.com/github/hidruspa/An-lise-barragem-hidreletrica/blob/main/An%C3%A1lise_de_seguran%C3%A7a_das_barragens_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análise de segurança das barragens - 1
#
# Neste notebook, estaremos fazendo um tratamento inicial na tabela, além de fazer uma análise inicial com alguma colunas
#
# O dataset foi extraido do portal de dados abertos que pode ser encontrado [aqui](https://dadosabertos.aneel.gov.br/dataset/fsb-fiscalizacao-de-seguranca-de-barragens). Ele vai ser usado como base e pode futuramento usar outros dados e fazer a cruzamento de informações

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
seg_bar = pd.read_csv('fiscalizacao-seguranca-barragem.csv',encoding='latin1',sep=';')
seg_bar.head()
# Out:
#   DatGeracaoConjuntoDados  IdeNucleoCEG       NomUsina  \
# 0              2024-05-01          66.0  Alto Araguaia
# 1              2024-05-01          76.0    Alto Jatapu
# 2              2024-05-01          76.0    Alto Jatapu
# 3              2024-05-01          76.0    Alto Jatapu
# 4              2024-05-01          76.0    Alto Jatapu
#
#                NomEmpresa       NomBarramento   DscTipo  \
# 0  PRIMAVERA ENERGIA S.A.       Alto Araguaia  Barragem
# 1    Roraima Energia S.A.  BARRAGEM PRINCIPAL  Barragem
# 2    Roraima Energia S.A.          VERTEDOURO  Barragem
# 3    Roraima Energia S.A.               USINA  Barragem
# 4    Roraima Energia S.A.           DIQUE N°1     Dique
#
#   DscNivelSegurancaBarragem IdcClassificacaoBarragens DscCategoriaRiscoGeral  \
# 0                    Normal                         C                  BAIXO
# 1                    Normal                         C                  BAIXO
# 2                    Normal                         C                  BAIXO
# 3                    Normal                         C                  BAIXO
# 4                    Normal                         C                  BAIXO
#
#   DscDanoPotencialGeral  ... DatConclusaoISE DatPrevistaConclusaoISE  \
# 0                 BAIXO  ...      1900-01-01                     NaN
# 1                 BAIXO  ...      1900-01-01                     NaN
# 2                 BAIXO  ...      1900-01-01                     NaN
# 3                 BAIXO  ...      1900-01-01                     NaN
# 4                 BAIXO  ...      1900-01-01                     NaN
#
#   QtdMunicipioAfetado MdaVazaoVertedouro MdaCotaCoroamentoBarramento  \
# 0                   0                NaN                         NaN
# 1                   0                NaN                         NaN
# 2                   0                NaN                         NaN
# 3                   0                NaN                         NaN
# 4                   0                NaN                         NaN
#
#   NomTipoEstrutural DscTipoEstrutural DscEstudoRompimento DscFinalidade  \
# 0    Sem Informação    Sem Informação                 NaN           NaN
# 1    Sem Informação    Sem Informação                 NaN           NaN
# 2    Sem Informação    Sem Informação                 NaN           NaN
# 3    Sem Informação    Sem Informação                 NaN           NaN
# 4    Sem Informação    Sem Informação                 NaN           NaN
#
#   DscEnquadraResolucao
# 0                  Não
# 1                  Sim
# 2                  Sim
# 3                  Sim
# 4                  Sim
#
# [5 rows x 86 columns]

# %%
seg_bar.shape
# Out:
# (11596, 86)

# %%
seg_bar['DatGeracaoConjuntoDados'].unique()
# Out:
# array(['2024-05-01'], dtype=object)

# %% [markdown]
# Temos que os dados foram atualizados no dia 2024-05-01 então como essa coluna só tem esse valor ela vai ser excluida pois só tem esse valor na coluna

# %%
seg_bar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11596 entries, 0 to 11595
# Data columns (total 86 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   DatGeracaoConjuntoDados         11596 non-null  object
#  1   IdeNucleoCEG                    11477 non-null  float64
#  2   NomUsina                        11477 non-null  object
#  3   NomEmpresa                      11477 non-null  object
#  4   NomBarramento                   11591 non-null  object
#  5   DscTipo                         11596 non-null  object
#  6   DscNivelSegurancaBarragem       11596 non-null  object
#  7   IdcClassificacaoBarragens       10486 non-null  object
#  8   DscCategoriaRiscoGeral          10486 non-null  object
#  9   DscDanoPotencialGeral           11596 non-null  object
#  10  DscVersao                       11596 non-null  object
#  11  NomCampanha                     11596 non-null  object
#  12  DatInicioCampanha               11596 non-null  object
#  13  DatFimCampanha                  11596 non-null  object
#  14  DatInicioPrazoLegalCampanha     11596 non-null  object
#  15  DatFimPrazoLegalCampanha        11596 non-null  object
#  16  NomSecundario                   8684 non-null   object
#  17  DatInicioConstrucao             2939 non-null   object
#  18  DatConclusaoConstrucao          11596 non-null  object
#  19  MdaAlturaMacicoTerreno          8595 non-null   object
#  20  MdaAlturaMacicoFundacao         11593 non-null  object
#  21  MdaComprimento                  11596 non-null  object
#  22  NumBarramento                   11596 non-null  int64
#  23  DscExisteAcidenteIncidente      11596 non-null  object
#  24  QtdAcidenteIncidente            11596 non-null  int64
#  25  MdaLatitude                     158 non-null    object
#  26  MdaLongitude                    158 non-null    object
#  27  DthCadastro                     11596 non-null  object
#  28  DthEnvio                        11596 non-null  object
#  29  DscEnvioPrazoLegal              11596 non-null  object
#  30  NomRioEmpreendimento            11596 non-null  object
#  31  MdaCapacidadeTotalEmp           11596 non-null  object
#  32  DatPrimeiroEnchimento           11497 non-null  object
#  33  DscFaseVidaEmpreendimento       11596 non-null  object
#  34  QtdBarramentoEmpreendimento     11596 non-null  int64
#  35  MdaAreaSuperficieReservatorio   11596 non-null  object
#  36  NumCnpj                         11477 non-null  float64
#  37  MdaPotenciaImplantacao          11477 non-null  object
#  38  PctParticipacaoEmpreendimento   11477 non-null  object
#  39  CodCEG                          11477 non-null  object
#  40  NomFonteEnergia                 11477 non-null  object
#  41  SigEstadoUsina                  11477 non-null  object
#  42  DscFaseUsina                    11477 non-null  object
#  43  DscTipoGeracao                  11477 non-null  object
#  44  DscTipoFundacao                 11332 non-null  object
#  45  DscTipoConstrucaoBarragem       11332 non-null  object
#  46  DscEstimativaVazaoProjeto       9081 non-null   object
#  47  DscCasaForca                    11332 non-null  object
#  48  DscComprimento                  11332 non-null  object
#  49  DscIdadeBarragem                11332 non-null  object
#  50  DscAltura                       11332 non-null  object
#  51  DscExisteDeformacao             10486 non-null  object
#  52  DscCondicaoEclusa               10486 non-null  object
#  53  DscCondicaoDeterioracao         10486 non-null  object
#  54  DscPercolacao                   10486 non-null  object
#  55  DscConfEstruturasAducao         10486 non-null  object
#  56  DscConfEstruturaExtravasora     10486 non-null  object
#  57  DscExisteDocumentacaoProjeto    10486 non-null  object
#  58  DscPossuiTecnicoEstrutura       10486 non-null  object
#  59  DscPossuiInspecaoMonitoramento  10486 non-null  object
#  60  DscRegraOperDispositivo         10486 non-null  object
#  61  DscEmiteRelatorio               10486 non-null  object
#  62  DscTamanhoVolumeReservatorio    11596 non-null  object
#  63  DscProbabilidadeMorte           11596 non-null  object
#  64  DscImpactoAmbiental             11596 non-null  object
#  65  DscImpactoSocioEconomico        11596 non-null  object
#  66  DscPSBElaborado                 11596 non-null  object
#  67  DatConclusaoPSB                 8845 non-null   object
#  68  DatPrevistaConclusaoPSB         255 non-null    object
#  69  DscPAEElaborado                 11596 non-null  object
#  70  DatConclusaoPAE                 8306 non-null   object
#  71  DatPrevistaConclusaoPAE         125 non-null    object
#  72  DscISRRealizada                 11596 non-null  object
#  73  DatConclusaoISR                 8909 non-null   object
#  74  DatPrevistaConclusaoISR         246 non-null    object
#  75  DscISERealizada                 11596 non-null  object
#  76  DatConclusaoISE                 3390 non-null   object
#  77  DatPrevistaConclusaoISE         254 non-null    object
#  78  QtdMunicipioAfetado             11596 non-null  int64
#  79  MdaVazaoVertedouro              7005 non-null   object
#  80  MdaCotaCoroamentoBarramento     7005 non-null   object
#  81  NomTipoEstrutural               11596 non-null  object
#  82  DscTipoEstrutural               11596 non-null  object
#  83  DscEstudoRompimento             6987 non-null   object
#  84  DscFinalidade                   5240 non-null   object
#  85  DscEnquadraResolucao            11596 non-null  object
# dtypes: float64(2), int64(4), object(80)
# memory usage: 7.6+ MB

# %% [markdown]
# dados as informações acima, iremos excluir as seguintes colunas por terem muitas inforamções em branco: MdaLatitude, MdaLongitude, DatPrevistaConclusaoPSB, DatPrevistaConclusaoPAE , DatPrevistaConclusaoISR, DatPrevistaConclusaoISE
#
# Além da coluna DatGeracaoConjuntoDados como foi explicado acima

# %%
seg_bar.drop(['MdaLatitude', 'MdaLongitude', 'DatPrevistaConclusaoPSB', 'DatPrevistaConclusaoPAE',
              'DatPrevistaConclusaoISR', 'DatPrevistaConclusaoISE','DatGeracaoConjuntoDados'],
             axis=1,inplace=True)
seg_bar.head()
# Out:
#    IdeNucleoCEG       NomUsina              NomEmpresa       NomBarramento  \
# 0          66.0  Alto Araguaia  PRIMAVERA ENERGIA S.A.       Alto Araguaia
# 1          76.0    Alto Jatapu    Roraima Energia S.A.  BARRAGEM PRINCIPAL
# 2          76.0    Alto Jatapu    Roraima Energia S.A.          VERTEDOURO
# 3          76.0    Alto Jatapu    Roraima Energia S.A.               USINA
# 4          76.0    Alto Jatapu    Roraima Energia S.A.           DIQUE N°1
#
#     DscTipo DscNivelSegurancaBarragem IdcClassificacaoBarragens  \
# 0  Barragem                    Normal                         C
# 1  Barragem                    Normal                         C
# 2  Barragem                    Normal                         C
# 3  Barragem                    Normal                         C
# 4     Dique                    Normal                         C
#
#   DscCategoriaRiscoGeral DscDanoPotencialGeral      DscVersao  ...  \
# 0                  BAIXO                 BAIXO  Retificação 2  ...
# 1                  BAIXO                 BAIXO  Retificação 2  ...
# 2                  BAIXO                 BAIXO  Retificação 2  ...
# 3                  BAIXO                 BAIXO  Retificação 2  ...
# 4                  BAIXO                 BAIXO  Retificação 2  ...
#
#   DscISERealizada DatConclusaoISE QtdMunicipioAfetado MdaVazaoVertedouro  \
# 0             Não      1900-01-01                   0                NaN
# 1             Não      1900-01-01                   0                NaN
# 2             Não      1900-01-01                   0                NaN
# 3             Não      1900-01-01                   0                NaN
# 4             Não      1900-01-01                   0                NaN
#
#   MdaCotaCoroamentoBarramento NomTipoEstrutural DscTipoEstrutural  \
# 0                         NaN    Sem Informação    Sem Informação
# 1                         NaN    Sem Informação    Sem Informação
# 2                         NaN    Sem Informação    Sem Informação
# 3                         NaN    Sem Informação    Sem Informação
# 4                         NaN    Sem Informação    Sem Informação
#
#   DscEstudoRompimento DscFinalidade DscEnquadraResolucao
# 0                 NaN           NaN                  Não
# 1                 NaN           NaN                  Sim
# 2                 NaN           NaN                  Sim
# 3                 NaN           NaN                  Sim
# 4                 NaN           NaN                  Sim
#
# [5 rows x 79 columns]

# %%
seg_bar.iloc[:,0:11].head()
# Out:
#    IdeNucleoCEG       NomUsina              NomEmpresa       NomBarramento  \
# 0          66.0  Alto Araguaia  PRIMAVERA ENERGIA S.A.       Alto Araguaia
# 1          76.0    Alto Jatapu    Roraima Energia S.A.  BARRAGEM PRINCIPAL
# 2          76.0    Alto Jatapu    Roraima Energia S.A.          VERTEDOURO
# 3          76.0    Alto Jatapu    Roraima Energia S.A.               USINA
# 4          76.0    Alto Jatapu    Roraima Energia S.A.           DIQUE N°1
#
#     DscTipo DscNivelSegurancaBarragem IdcClassificacaoBarragens  \
# 0  Barragem                    Normal                         C
# 1  Barragem                    Normal                         C
# 2  Barragem                    Normal                         C
# 3  Barragem                    Normal                         C
# 4     Dique                    Normal                         C
#
#   DscCategoriaRiscoGeral DscDanoPotencialGeral      DscVersao      NomCampanha
# 0                  BAIXO                 BAIXO  Retificação 2  Campanha 2016/1
# 1                  BAIXO                 BAIXO  Retificação 2  Campanha 2016/1
# 2                  BAIXO                 BAIXO  Retificação 2  Campanha 2016/1
# 3                  BAIXO                 BAIXO  Retificação 2  Campanha 2016/1
# 4                  BAIXO                 BAIXO  Retificação 2  Campanha 2016/1

# %% [markdown]
# ### Dicionário dos dados
#
# Colunas e o que seignicam (as que serão feita análise nesse notebook)
#
# - **IdeNucleoCEG**: Núcleo do Código Único de Empreendimentos de Geração
# - **NomUsina**: Nome da usina/empreendimento
# - **NomEmpresa**: Nome da empresa responsável pelo empreendimento
# - **NomBarramento**: Nome do Barramento que faz do empreendimento
# - **DscTipo**: Armazena o Tipo do Barramento
# - **DscNivelSegurancaBarragem**: Define o nível de segurança do barramento
# - **IdcClassificacaoBarragens**: Define a classificação do barramento. Notas: A, B ou C.
# - **DscCategoriaRiscoGeral**: Define o valor da categoria de risco geral do barramento.
# - **DscDanoPotencialGeral**: Define o valor do dano potencial geral do barramento
# - **DscVersao**: Número da versão
# - **NomCampanha**: Número da campanha

# %%
plt.title('Tipo de Barramento',fontsize=14)
plt.pie(seg_bar['DscTipo'].value_counts(),labels=seg_bar['DscTipo'].value_counts().index,
        autopct='%1.1f%%');

# %%
plt.title('Classificação do barramento',fontsize=14)
sns.countplot(x='IdcClassificacaoBarragens',data=seg_bar)
plt.xlabel('Classificação')
plt.ylabel('Quantidade');

# %%
plt.title('Nivel de segurança das barragens',fontsize=14)
sns.countplot(x='DscNivelSegurancaBarragem',data=seg_bar)
plt.xlabel('Nivel de segurança')
plt.ylabel('Quantidade')
# Out:
# Text(0, 0.5, 'Quantidade')

# %%
plt.title('Risco geral do barramento',fontsize=14)
sns.countplot(x='DscCategoriaRiscoGeral',data=seg_bar)
plt.xlabel('Risco')
plt.ylabel('Quantidade');

# %%
plt.title('Dano potencial do barramento',fontsize=14)
sns.countplot(x='DscDanoPotencialGeral',data=seg_bar)
plt.xlabel('Dano')
plt.ylabel('Quantidade');

# %%
plt.title('Tipo de barramento em relação a classificação',fontsize=14)
sns.countplot(x='DscTipo',hue='IdcClassificacaoBarragens',data=seg_bar)
plt.xlabel('Tipo')
plt.ylabel('Quantidade')
plt.legend(title='Classificação');

# %%
plt.title('Tipo de barramento em relação ao risco',fontsize=14)
sns.countplot(x='DscTipo',hue='DscCategoriaRiscoGeral',data=seg_bar)
plt.xlabel('Tipo')
plt.ylabel('Quantidade')
plt.legend(title='Risco');

# %%
plt.title('Tipo de barramento em relação ao dano',fontsize=14)
sns.countplot(x='DscTipo',hue='DscDanoPotencialGeral',data=seg_bar)
plt.xlabel('Tipo')
plt.ylabel('Quantidade')
plt.legend(title='Dano');

# %%
plt.title('Risco geral do barramento em relação ao dano',fontsize=14)
sns.countplot(x='DscCategoriaRiscoGeral',data=seg_bar,hue='DscDanoPotencialGeral')
plt.xlabel('Risco')
plt.ylabel('Quantidade')
plt.legend(title='Risco');

# %%
plt.title('Nivel de segurança das barragens',fontsize=14)
sns.countplot(x='DscNivelSegurancaBarragem',data=seg_bar, hue='DscDanoPotencialGeral')
plt.xlabel('Nivel de segurança')
plt.ylabel('Quantidade')
# Out:
# Text(0, 0.5, 'Quantidade')

# %%
import plotly.express as px
px.parallel_categories(seg_bar.iloc[:,4:9],color_continuous_scale=px.colors.sequential.Inferno)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="53cb36d7-89a0-4011-a666-b013403421c5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("53cb36d7-89a0-4011-a666-b013403421c5")) {                    Plotly.newPlot(                        "53cb36d7-89a0-4011-a666-b013403421c5",                        [{"dimensions":[{"label":"DscTipo","values":["Barragem","Barragem","Barragem","Barragem","Dique","Dique","Dique","Dique","Dique","Dique","Dique","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Dique","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Dique","Barragem","Barragem","Barragem","Barragem","Barragem","Dique","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Dique","Dique","Dique","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Dique","Dique","Dique","Dique","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Dique","Dique","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Dique","Dique","Dique","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Dique","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Dique","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Dique","Dique","Dique","Dique","Dique","Dique","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Dique","Dique","Dique","Dique","Dique","Dique","Barragem","Barragem","Barragem","Barragem","Barragem","Dique","Dique","Barragem","Barragem","Barragem","Dique","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Dique","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Dique","Barragem","Barragem","Barragem","Dique","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Dique","Dique","Dique","Dique","Dique","Dique","Dique","Dique","Dique","Dique","Dique","Dique","Dique","Dique","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Dique","Dique","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Barragem","Dique","Barragem","Barr ...
